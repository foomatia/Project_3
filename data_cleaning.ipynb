# %%
import pandas as pd

# Read the data into a Pandas DataFrame with explicit encoding
# Assuming 'utf-8' encoding, change it if needed
df = pd.read_csv("Resources/State_funded_schools_inspections_and_outcomes_as_at_31_August_2023.csv", encoding='latin-1')

# Display the first few rows of the DataFrame
df.head()
# Out:
# C:\Users\Ryan\AppData\Local\Temp\ipykernel_15652\1495132719.py:5: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Resources/State_funded_schools_inspections_and_outcomes_as_at_31_August_2023.csv", encoding='latin-1')
#                                             Web Link       URN    LAESTAB  \
# 0  http://www.ofsted.gov.uk/inspection-reports/fi...  100000.0  2013614.0
# 1  http://www.ofsted.gov.uk/inspection-reports/fi...  100005.0  2021048.0
# 2  http://www.ofsted.gov.uk/inspection-reports/fi...  100006.0  2021100.0
# 3  http://www.ofsted.gov.uk/inspection-reports/fi...  100007.0  2021101.0
# 4  http://www.ofsted.gov.uk/inspection-reports/fi...  100008.0  2022019.0
#
#                           School name Ofsted phase       Type of education  \
# 0                  The Aldgate School      Primary  Voluntary Aided School
# 1                 Thomas Coram Centre      Nursery       LA Nursery School
# 2                        Heath School          PRU     Pupil Referral Unit
# 3  Camden Primary Pupil Referral Unit          PRU     Pupil Referral Unit
# 4               Argyle Primary School      Primary        Community School
#
#   School open date Admissions policy                  Sixth form  \
# 0              NaN    Not applicable  Does not have a sixth form
# 1              NaN    Not applicable              Not applicable
# 2       01/09/1999    Not applicable              Not applicable
# 3              NaN    Not applicable              Not applicable
# 4              NaN    Not applicable  Does not have a sixth form
#
#   Designated religious character  ...  \
# 0              Church of England  ...
# 1                 Does not apply  ...
# 2                 Does not apply  ...
# 3                 Does not apply  ...
# 4                 Does not apply  ...
#
#   School type at time of previous graded inspection  \
# 0                            Voluntary Aided School
# 1                                 LA Nursery School
# 2                               Pupil Referral Unit
# 3                               Pupil Referral Unit
# 4                                  Community School
#
#   Previous graded inspection overall effectiveness  \
# 0                                              1.0
# 1                                              1.0
# 2                                              2.0
# 3                                              2.0
# 4                                              2.0
#
#   Previous category of concern Previous quality of education  \
# 0                          NaN                           9.0
# 1                          NaN                           9.0
# 2                          NaN                           9.0
# 3                          NaN                           9.0
# 4                          NaN                           9.0
#
#   Previous behaviour and attitudes Previous personal development  \
# 0                              9.0                           9.0
# 1                              9.0                           9.0
# 2                              9.0                           9.0
# 3                              9.0                           9.0
# 4                              9.0                           9.0
#
#    Previous effectiveness of leadership and management  \
# 0                                                1.0
# 1                                                1.0
# 2                                                2.0
# 3                                                2.0
# 4                                                2.0
#
#   Previous safeguarding is effective?  \
# 0                                   9
# 1                                   9
# 2                                   9
# 3                                   9
# 4                                   9
#
#    Previous early years provision (where applicable)  \
# 0                                                1.0
# 1                                                1.0
# 2                                                9.0
# 3                                                9.0
# 4                                                2.0
#
#   Previous sixth form provision (where applicable)
# 0                                              9.0
# 1                                              9.0
# 2                                              9.0
# 3                                              9.0
# 4                                              9.0
#
# [5 rows x 78 columns]

# %%
df.columns
# Out:
# Index(['Web Link', 'URN', 'LAESTAB', 'School name', 'Ofsted phase',
#        'Type of education', 'School open date', 'Admissions policy',
#        'Sixth form', 'Designated religious character', 'Religious ethos',
#        'Faith grouping', 'Ofsted region', 'Region', 'Local authority',
#        'Parliamentary constituency', 'Multi-academy trust UID',
#        'Multi-academy trust name', 'Academy sponsor UID',
#        'Academy sponsor name', 'Postcode',
#        'Number of warning notices issued in 2022/23 academic year',
#        'The income deprivation affecting children index (IDACI) quintile',
#        'Total number of pupils', 'Statutory lowest age',
#        'Statutory highest age',
#        'Latest ungraded inspection number since last graded inspection',
#        'Does the ungraded inspection relate to the URN of the current school?',
#        'URN at time of the ungraded inspection',
#        'LAESTAB at time of the ungraded inspection',
#        'School name at time of the ungraded inspection',
#        'School type at time of the ungraded inspection',
#        'Number of ungraded inspections since the last graded inspection',
#        'Date of latest ungraded inspection',
#        'Ungraded inspection publication date',
#        'Did the latest ungraded inspection convert to a graded inspection?',
#        'Ungraded inspection overall outcome',
#        'Number of monitoring and urgent inspections since last graded inspection',
#        'Inspection number of latest graded inspection', 'Inspection type',
#        'Inspection type grouping', 'Event type grouping',
#        'Inspection start date', 'Inspection end date', 'Publication date',
#        'Does the latest graded inspection relate to the URN of the current school?',
#        'URN at time of latest graded inspection',
#        'LAESTAB at time of latest graded inspection',
#        'School name at time of latest graded inspection',
#        'School type at time of latest graded inspection',
#        'Current school type used for chart C6', 'Overall effectiveness',
#        'Category of concern', 'Quality of education',
#        'Behaviour and attitudes', 'Personal development',
#        'Effectiveness of leadership and management',
#        'Safeguarding is effective?',
#        'Early years provision (where applicable)',
#        'Sixth form provision (where applicable)', 'Previous inspection number',
#        'Previous inspection start date', 'Previous inspection end date',
#        'Previous publication date',
#        'Does the previous graded inspection relate to the URN of the current school?',
#        'URN at time of previous graded inspection',
#        'LAESTAB at time of previous graded inspection',
#        'School name at time of previous graded inspection',
#        'School type at time of previous graded inspection',
#        'Previous graded inspection overall effectiveness',
#        'Previous category of concern', 'Previous quality of education',
#        'Previous behaviour and attitudes', 'Previous personal development',
#        'Previous effectiveness of leadership and management',
#        'Previous safeguarding is effective?',
#        'Previous early years provision (where applicable)',
#        'Previous sixth form provision (where applicable)'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                 Web Link       URN    LAESTAB  \
# 0      http://www.ofsted.gov.uk/inspection-reports/fi...  100000.0  2013614.0
# 1      http://www.ofsted.gov.uk/inspection-reports/fi...  100005.0  2021048.0
# 2      http://www.ofsted.gov.uk/inspection-reports/fi...  100006.0  2021100.0
# 3      http://www.ofsted.gov.uk/inspection-reports/fi...  100007.0  2021101.0
# 4      http://www.ofsted.gov.uk/inspection-reports/fi...  100008.0  2022019.0
# ...                                                  ...       ...        ...
# 22004                                                NaN       NaN        NaN
# 22005                                                NaN       NaN        NaN
# 22006                                                NaN       NaN        NaN
# 22007                                                NaN       NaN        NaN
# 22008                                                NaN       NaN        NaN
#
#                               School name Ofsted phase  \
# 0                      The Aldgate School      Primary
# 1                     Thomas Coram Centre      Nursery
# 2                            Heath School          PRU
# 3      Camden Primary Pupil Referral Unit          PRU
# 4                   Argyle Primary School      Primary
# ...                                   ...          ...
# 22004                                 NaN          NaN
# 22005                                 NaN          NaN
# 22006                                 NaN          NaN
# 22007                                 NaN          NaN
# 22008                                 NaN          NaN
#
#             Type of education School open date Admissions policy  \
# 0      Voluntary Aided School              NaN    Not applicable
# 1           LA Nursery School              NaN    Not applicable
# 2         Pupil Referral Unit       01/09/1999    Not applicable
# 3         Pupil Referral Unit              NaN    Not applicable
# 4            Community School              NaN    Not applicable
# ...                       ...              ...               ...
# 22004                     NaN              NaN               NaN
# 22005                     NaN              NaN               NaN
# 22006                     NaN              NaN               NaN
# 22007                     NaN              NaN               NaN
# 22008                     NaN              NaN               NaN
#
#                        Sixth form Designated religious character  ...  \
# 0      Does not have a sixth form              Church of England  ...
# 1                  Not applicable                 Does not apply  ...
# 2                  Not applicable                 Does not apply  ...
# 3                  Not applicable                 Does not apply  ...
# 4      Does not have a sixth form                 Does not apply  ...
# ...                           ...                            ...  ...
# 22004                         NaN                            NaN  ...
# 22005                         NaN                            NaN  ...
# 22006                         NaN                            NaN  ...
# 22007                         NaN                            NaN  ...
# 22008                         NaN                            NaN  ...
#
#       School type at time of previous graded inspection  \
# 0                                Voluntary Aided School
# 1                                     LA Nursery School
# 2                                   Pupil Referral Unit
# 3                                   Pupil Referral Unit
# 4                                      Community School
# ...                                                 ...
# 22004                                               NaN
# 22005                                               NaN
# 22006                                               NaN
# 22007                                               NaN
# 22008                                               NaN
#
#       Previous graded inspection overall effectiveness  \
# 0                                                  1.0
# 1                                                  1.0
# 2                                                  2.0
# 3                                                  2.0
# 4                                                  2.0
# ...                                                ...
# 22004                                              NaN
# 22005                                              NaN
# 22006                                              NaN
# 22007                                              NaN
# 22008                                              NaN
#
#       Previous category of concern Previous quality of education  \
# 0                              NaN                           9.0
# 1                              NaN                           9.0
# 2                              NaN                           9.0
# 3                              NaN                           9.0
# 4                              NaN                           9.0
# ...                            ...                           ...
# 22004                          NaN                           NaN
# 22005                          NaN                           NaN
# 22006                          NaN                           NaN
# 22007                          NaN                           NaN
# 22008                          NaN                           NaN
#
#       Previous behaviour and attitudes Previous personal development  \
# 0                                  9.0                           9.0
# 1                                  9.0                           9.0
# 2                                  9.0                           9.0
# 3                                  9.0                           9.0
# 4                                  9.0                           9.0
# ...                                ...                           ...
# 22004                              NaN                           NaN
# 22005                              NaN                           NaN
# 22006                              NaN                           NaN
# 22007                              NaN                           NaN
# 22008                              NaN                           NaN
#
#        Previous effectiveness of leadership and management  \
# 0                                                    1.0
# 1                                                    1.0
# 2                                                    2.0
# 3                                                    2.0
# 4                                                    2.0
# ...                                                  ...
# 22004                                                NaN
# 22005                                                NaN
# 22006                                                NaN
# 22007                                                NaN
# 22008                                                NaN
#
#       Previous safeguarding is effective?  \
# 0                                       9
# 1                                       9
# 2                                       9
# 3                                       9
# 4                                       9
# ...                                   ...
# 22004                                 NaN
# 22005                                 NaN
# 22006                                 NaN
# 22007                                 NaN
# 22008                                 NaN
#
#        Previous early years provision (where applicable)  \
# 0                                                    1.0
# 1                                                    1.0
# 2                                                    9.0
# 3                                                    9.0
# 4                                                    2.0
# ...                                                  ...
# 22004                                                NaN
# 22005                                                NaN
# 22006                                                NaN
# 22007                                                NaN
# 22008                                                NaN
#
#       Previous sixth form provision (where applicable)
# 0                                                  9.0
# 1                                                  9.0
# 2                                                  9.0
# 3                                                  9.0
# 4                                                  9.0
# ...                                                ...
# 22004                                              NaN
# 22005                                              NaN
# 22006                                              NaN
# 22007                                              NaN
# 22008                                              NaN
#
# [22009 rows x 78 columns]>

# %%
# Reduced df of columns
reduced_df = df[["Web Link","URN","School name","Ofsted phase","Ofsted region","Local authority",
                 "Postcode","Total number of pupils","Inspection start date","Inspection end date",
                 "Publication date","Does the latest graded inspection relate to the URN of the current school?",
                 "Overall effectiveness","Category of concern","Quality of education","Behaviour and attitudes",
                 "Personal development","Effectiveness of leadership and management","Safeguarding is effective?"]]

reduced_df.head()
# Out:
#                                             Web Link       URN  \
# 0  http://www.ofsted.gov.uk/inspection-reports/fi...  100000.0
# 1  http://www.ofsted.gov.uk/inspection-reports/fi...  100005.0
# 2  http://www.ofsted.gov.uk/inspection-reports/fi...  100006.0
# 3  http://www.ofsted.gov.uk/inspection-reports/fi...  100007.0
# 4  http://www.ofsted.gov.uk/inspection-reports/fi...  100008.0
#
#                           School name Ofsted phase Ofsted region  \
# 0                  The Aldgate School      Primary        London
# 1                 Thomas Coram Centre      Nursery        London
# 2                        Heath School          PRU        London
# 3  Camden Primary Pupil Referral Unit          PRU        London
# 4               Argyle Primary School      Primary        London
#
#   Local authority  Postcode  Total number of pupils Inspection start date  \
# 0  City of London  EC3A 5DE                   277.0            18/04/2013
# 1          Camden  WC1N 2NY                   128.0            05/06/2014
# 2          Camden   NW3 2NY                    38.0            24/04/2014
# 3          Camden   NW1 3EX                    17.0            26/03/2015
# 4          Camden  WC1H 9EG                   366.0            04/10/2022
#
#   Inspection end date Publication date  \
# 0          19/04/2013       14/05/2013
# 1          06/06/2014       02/07/2014
# 2          25/04/2014       21/05/2014
# 3          27/03/2015       05/05/2015
# 4          05/10/2022       17/11/2022
#
#   Does the latest graded inspection relate to the URN of the current school?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#    Overall effectiveness Category of concern  Quality of education  \
# 0                    1.0                 NaN                   9.0
# 1                    1.0                 NaN                   9.0
# 2                    2.0                 NaN                   9.0
# 3                    2.0                 NaN                   9.0
# 4                    2.0                 NaN                   2.0
#
#    Behaviour and attitudes  Personal development  \
# 0                      9.0                   9.0
# 1                      9.0                   9.0
# 2                      9.0                   9.0
# 3                      9.0                   9.0
# 4                      2.0                   1.0
#
#    Effectiveness of leadership and management Safeguarding is effective?
# 0                                         1.0                          9
# 1                                         1.0                          9
# 2                                         2.0                          9
# 3                                         2.0                          9
# 4                                         2.0                        Yes

# %%
# Show dtypes
reduced_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22009 entries, 0 to 22008
# Data columns (total 19 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   Web Link                                                                    22000 non-null  object
#  1   URN                                                                         22000 non-null  float64
#  2   School name                                                                 22000 non-null  object
#  3   Ofsted phase                                                                22000 non-null  object
#  4   Ofsted region                                                               22000 non-null  object
#  5   Local authority                                                             22000 non-null  object
#  6   Postcode                                                                    22000 non-null  object
#  7   Total number of pupils                                                      21412 non-null  float64
#  8   Inspection start date                                                       21807 non-null  object
#  9   Inspection end date                                                         21807 non-null  object
#  10  Publication date                                                            21807 non-null  object
#  11  Does the latest graded inspection relate to the URN of the current school?  21807 non-null  object
#  12  Overall effectiveness                                                       21807 non-null  float64
#  13  Category of concern                                                         556 non-null    object
#  14  Quality of education                                                        21807 non-null  float64
#  15  Behaviour and attitudes                                                     21807 non-null  float64
#  16  Personal development                                                        21807 non-null  float64
#  17  Effectiveness of leadership and management                                  21807 non-null  float64
#  18  Safeguarding is effective?                                                  21807 non-null  object
# dtypes: float64(7), object(12)
# memory usage: 3.2+ MB

# %% [markdown]
# ### Grades
# 1 = Outstanding /n
# 2 = Good /n
# 3 = Requires Improvement /n
# 4 = Inadequate /n
# 9/NaN = Insufficient Evidence /n

# %%
# Mass value change of Ofsted Grades for ease of understanding
reduced_df[['Overall effectiveness','Quality of education',
            'Behaviour and attitudes','Personal development',
            'Effectiveness of leadership and management']] = reduced_df[['Overall effectiveness','Quality of education',
                                                                         'Behaviour and attitudes','Personal development',
                                                                         'Effectiveness of leadership and management']].replace({1.0:"Outstanding",
                                                                                                                                2.0:"Good",
                                                                                                                                3.0:"Requires Improvement",
                                                                                                                                4.0:"Inadequate",
                                                                                                                                9.0:"Insufficient Evidence"})

reduced_df.head()
# Out:
# C:\Users\Ryan\AppData\Local\Temp\ipykernel_15652\1313770966.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df[['Overall effectiveness','Quality of education',
#                                             Web Link       URN  \
# 0  http://www.ofsted.gov.uk/inspection-reports/fi...  100000.0
# 1  http://www.ofsted.gov.uk/inspection-reports/fi...  100005.0
# 2  http://www.ofsted.gov.uk/inspection-reports/fi...  100006.0
# 3  http://www.ofsted.gov.uk/inspection-reports/fi...  100007.0
# 4  http://www.ofsted.gov.uk/inspection-reports/fi...  100008.0
#
#                           School name Ofsted phase Ofsted region  \
# 0                  The Aldgate School      Primary        London
# 1                 Thomas Coram Centre      Nursery        London
# 2                        Heath School          PRU        London
# 3  Camden Primary Pupil Referral Unit          PRU        London
# 4               Argyle Primary School      Primary        London
#
#   Local authority  Postcode  Total number of pupils Inspection start date  \
# 0  City of London  EC3A 5DE                   277.0            18/04/2013
# 1          Camden  WC1N 2NY                   128.0            05/06/2014
# 2          Camden   NW3 2NY                    38.0            24/04/2014
# 3          Camden   NW1 3EX                    17.0            26/03/2015
# 4          Camden  WC1H 9EG                   366.0            04/10/2022
#
#   Inspection end date Publication date  \
# 0          19/04/2013       14/05/2013
# 1          06/06/2014       02/07/2014
# 2          25/04/2014       21/05/2014
# 3          27/03/2015       05/05/2015
# 4          05/10/2022       17/11/2022
#
#   Does the latest graded inspection relate to the URN of the current school?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Overall effectiveness Category of concern   Quality of education  \
# 0           Outstanding                 NaN  Insufficient Evidence
# 1           Outstanding                 NaN  Insufficient Evidence
# 2                  Good                 NaN  Insufficient Evidence
# 3                  Good                 NaN  Insufficient Evidence
# 4                  Good                 NaN                   Good
#
#   Behaviour and attitudes   Personal development  \
# 0   Insufficient Evidence  Insufficient Evidence
# 1   Insufficient Evidence  Insufficient Evidence
# 2   Insufficient Evidence  Insufficient Evidence
# 3   Insufficient Evidence  Insufficient Evidence
# 4                    Good            Outstanding
#
#   Effectiveness of leadership and management Safeguarding is effective?
# 0                                Outstanding                          9
# 1                                Outstanding                          9
# 2                                       Good                          9
# 3                                       Good                          9
# 4                                       Good                        Yes

# %%
# Alter 'Safeguarding is effective?' column values
reduced_df['Safeguarding is effective?'] = reduced_df['Safeguarding is effective?'].replace({"9":"Insufficient Evidence"})

reduced_df.head()
# Out:
# C:\Users\Ryan\AppData\Local\Temp\ipykernel_15652\701873297.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['Safeguarding is effective?'] = reduced_df['Safeguarding is effective?'].replace({"9":"Insufficient Evidence"})
#                                             Web Link       URN  \
# 0  http://www.ofsted.gov.uk/inspection-reports/fi...  100000.0
# 1  http://www.ofsted.gov.uk/inspection-reports/fi...  100005.0
# 2  http://www.ofsted.gov.uk/inspection-reports/fi...  100006.0
# 3  http://www.ofsted.gov.uk/inspection-reports/fi...  100007.0
# 4  http://www.ofsted.gov.uk/inspection-reports/fi...  100008.0
#
#                           School name Ofsted phase Ofsted region  \
# 0                  The Aldgate School      Primary        London
# 1                 Thomas Coram Centre      Nursery        London
# 2                        Heath School          PRU        London
# 3  Camden Primary Pupil Referral Unit          PRU        London
# 4               Argyle Primary School      Primary        London
#
#   Local authority  Postcode  Total number of pupils Inspection start date  \
# 0  City of London  EC3A 5DE                   277.0            18/04/2013
# 1          Camden  WC1N 2NY                   128.0            05/06/2014
# 2          Camden   NW3 2NY                    38.0            24/04/2014
# 3          Camden   NW1 3EX                    17.0            26/03/2015
# 4          Camden  WC1H 9EG                   366.0            04/10/2022
#
#   Inspection end date Publication date  \
# 0          19/04/2013       14/05/2013
# 1          06/06/2014       02/07/2014
# 2          25/04/2014       21/05/2014
# 3          27/03/2015       05/05/2015
# 4          05/10/2022       17/11/2022
#
#   Does the latest graded inspection relate to the URN of the current school?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Overall effectiveness Category of concern   Quality of education  \
# 0           Outstanding                 NaN  Insufficient Evidence
# 1           Outstanding                 NaN  Insufficient Evidence
# 2                  Good                 NaN  Insufficient Evidence
# 3                  Good                 NaN  Insufficient Evidence
# 4                  Good                 NaN                   Good
#
#   Behaviour and attitudes   Personal development  \
# 0   Insufficient Evidence  Insufficient Evidence
# 1   Insufficient Evidence  Insufficient Evidence
# 2   Insufficient Evidence  Insufficient Evidence
# 3   Insufficient Evidence  Insufficient Evidence
# 4                    Good            Outstanding
#
#   Effectiveness of leadership and management Safeguarding is effective?
# 0                                Outstanding      Insufficient Evidence
# 1                                Outstanding      Insufficient Evidence
# 2                                       Good      Insufficient Evidence
# 3                                       Good      Insufficient Evidence
# 4                                       Good                        Yes

# %%
# Filter the data to only Primary or Seconday Phases
filtered_df = reduced_df.loc[(reduced_df["Ofsted phase"] == "Primary") | (reduced_df["Ofsted phase"] == "Secondary")]

# Filter the data to only West Midlands Region
filtered_df = filtered_df.loc[reduced_df["Ofsted region"] == "West Midlands"]

filtered_df.head()
# Out:
#                                                Web Link       URN  \
# 1429  http://www.ofsted.gov.uk/inspection-reports/fi...  103157.0
# 1430  http://www.ofsted.gov.uk/inspection-reports/fi...  103159.0
# 1431  http://www.ofsted.gov.uk/inspection-reports/fi...  103162.0
# 1432  http://www.ofsted.gov.uk/inspection-reports/fi...  103163.0
# 1433  http://www.ofsted.gov.uk/inspection-reports/fi...  103164.0
#
#                    School name Ofsted phase  Ofsted region Local authority  \
# 1429  Shaw Hill Primary School      Primary  West Midlands      Birmingham
# 1430   Adderley Primary School      Primary  West Midlands      Birmingham
# 1431    Barford Primary School      Primary  West Midlands      Birmingham
# 1432     Beeches Junior School      Primary  West Midlands      Birmingham
# 1433     Beeches Infant School      Primary  West Midlands      Birmingham
#
#      Postcode  Total number of pupils Inspection start date  \
# 1429   B8 3AN                   479.0            08/03/2017
# 1430   B8 1DZ                   483.0            13/12/2016
# 1431  B16 0EF                   407.0            14/11/2012
# 1432  B42 2PY                   362.0            08/10/2013
# 1433  B42 2PY                   270.0            27/06/2017
#
#      Inspection end date Publication date  \
# 1429          09/03/2017       24/04/2017
# 1430          14/12/2016       24/01/2017
# 1431          15/11/2012       05/12/2012
# 1432          09/10/2013       04/11/2013
# 1433          28/06/2017       20/07/2017
#
#      Does the latest graded inspection relate to the URN of the current school?  \
# 1429                                                Yes
# 1430                                                Yes
# 1431                                                Yes
# 1432                                                Yes
# 1433                                                Yes
#
#      Overall effectiveness Category of concern   Quality of education  \
# 1429           Outstanding                 NaN  Insufficient Evidence
# 1430                  Good                 NaN  Insufficient Evidence
# 1431                  Good                 NaN  Insufficient Evidence
# 1432                  Good                 NaN  Insufficient Evidence
# 1433                  Good                 NaN  Insufficient Evidence
#
#      Behaviour and attitudes   Personal development  \
# 1429   Insufficient Evidence  Insufficient Evidence
# 1430   Insufficient Evidence  Insufficient Evidence
# 1431   Insufficient Evidence  Insufficient Evidence
# 1432   Insufficient Evidence  Insufficient Evidence
# 1433   Insufficient Evidence  Insufficient Evidence
#
#      Effectiveness of leadership and management Safeguarding is effective?
# 1429                                Outstanding                        Yes
# 1430                                       Good                        Yes
# 1431                                       Good      Insufficient Evidence
# 1432                                       Good      Insufficient Evidence
# 1433                                       Good                        Yes

# %%
# Change NULL values in Num of Pupils to 0
filtered_df['Total number of pupils'] = filtered_df['Total number of pupils'].fillna(0)

# Alter column data types
filtered_df = filtered_df.astype({"URN":"int64",
                               "Total number of pupils":"int64",
                                 "Inspection start date":"datetime64",
                                 "Inspection end date":"datetime64",
                                 "Publication date":"datetime64"})

filtered_df.dtypes
# Out:
# C:\Users\Ryan\AppData\Local\Temp\ipykernel_15652\3312581040.py:5: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   filtered_df = filtered_df.astype({"URN":"int64",
# C:\Users\Ryan\AppData\Local\Temp\ipykernel_15652\3312581040.py:5: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   filtered_df = filtered_df.astype({"URN":"int64",
# C:\Users\Ryan\AppData\Local\Temp\ipykernel_15652\3312581040.py:5: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   filtered_df = filtered_df.astype({"URN":"int64",
# Web Link                                                                              object
# URN                                                                                    int64
# School name                                                                           object
# Ofsted phase                                                                          object
# Ofsted region                                                                         object
# Local authority                                                                       object
# Postcode                                                                              object
# Total number of pupils                                                                 int64
# Inspection start date                                                         datetime64[ns]
# Inspection end date                                                           datetime64[ns]
# Publication date                                                              datetime64[ns]
# Does the latest graded inspection relate to the URN of the current school?            object
# Overall effectiveness                                                                 object
# Category of concern                                                                   object
# Quality of education                                                                  object
# Behaviour and attitudes                                                               object
# Personal development                                                                  object
# Effectiveness of leadership and management                                            object
# Safeguarding is effective?                                                            object
# dtype: object

# %%
filtered_df = filtered_df.reset_index(drop=True)

filtered_df.head()
# Out:
#                                             Web Link     URN  \
# 0  http://www.ofsted.gov.uk/inspection-reports/fi...  103157
# 1  http://www.ofsted.gov.uk/inspection-reports/fi...  103159
# 2  http://www.ofsted.gov.uk/inspection-reports/fi...  103162
# 3  http://www.ofsted.gov.uk/inspection-reports/fi...  103163
# 4  http://www.ofsted.gov.uk/inspection-reports/fi...  103164
#
#                 School name Ofsted phase  Ofsted region Local authority  \
# 0  Shaw Hill Primary School      Primary  West Midlands      Birmingham
# 1   Adderley Primary School      Primary  West Midlands      Birmingham
# 2    Barford Primary School      Primary  West Midlands      Birmingham
# 3     Beeches Junior School      Primary  West Midlands      Birmingham
# 4     Beeches Infant School      Primary  West Midlands      Birmingham
#
#   Postcode  Total number of pupils Inspection start date Inspection end date  \
# 0   B8 3AN                     479            2017-08-03          2017-09-03
# 1   B8 1DZ                     483            2016-12-13          2016-12-14
# 2  B16 0EF                     407            2012-11-14          2012-11-15
# 3  B42 2PY                     362            2013-08-10          2013-09-10
# 4  B42 2PY                     270            2017-06-27          2017-06-28
#
#   Publication date  \
# 0       2017-04-24
# 1       2017-01-24
# 2       2012-05-12
# 3       2013-04-11
# 4       2017-07-20
#
#   Does the latest graded inspection relate to the URN of the current school?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Overall effectiveness Category of concern   Quality of education  \
# 0           Outstanding                 NaN  Insufficient Evidence
# 1                  Good                 NaN  Insufficient Evidence
# 2                  Good                 NaN  Insufficient Evidence
# 3                  Good                 NaN  Insufficient Evidence
# 4                  Good                 NaN  Insufficient Evidence
#
#   Behaviour and attitudes   Personal development  \
# 0   Insufficient Evidence  Insufficient Evidence
# 1   Insufficient Evidence  Insufficient Evidence
# 2   Insufficient Evidence  Insufficient Evidence
# 3   Insufficient Evidence  Insufficient Evidence
# 4   Insufficient Evidence  Insufficient Evidence
#
#   Effectiveness of leadership and management Safeguarding is effective?
# 0                                Outstanding                        Yes
# 1                                       Good                        Yes
# 2                                       Good      Insufficient Evidence
# 3                                       Good      Insufficient Evidence
# 4                                       Good                        Yes

# %%
# Update data types
reduced_df = reduced_df.astype({"URN":"int64",
                               "Total number of pupils":"int64",
                               "Overall effectiveness":"int64",
                               })

# %%
from geopy.geocoders import Nominatim
import pandas as pd

# Assuming df is your DataFrame
df = pd.read_csv("Resources/State_funded_schools_inspections_and_outcomes_as_at_31_August_2023.csv", encoding='latin-1')

# Create a geolocator using Nominatim
geolocator = Nominatim(user_agent="school_geocoder")

# Function to get latitude and longitude from address
def get_lat_lon(Postcode):
    location = geolocator.geocode(Postcode)
    return (location.latitude, location.longitude) if location else (None, None)

# Apply the function to the 'Postcode' column
df['Latitude'], df['Longitude'] = zip(*df['Postcode'].apply(get_lat_lon))

# Display the DataFrame with School name, Latitude, and Longitude columns
result_df = df[['School name', 'Latitude', 'Longitude']]
print(result_df)

# %%
result_df.head

# %%
def get_lat_lon(Postcode):
    location = geolocator.geocode(Postcode)
    print(location)  # Add this line to print the geocoding results
    return (location.latitude, location.longitude) if location else (None, None)

# %%
result_df.to_csv("Resources/result_df.csv")

# %%
import time

def get_lat_lon(Postcode):
    location = geolocator.geocode(Postcode)
    time.sleep(1)  # Add a 1-second delay to avoid rate limits
    return (location.latitude, location.longitude) if location else (None, None)

# %%
import pandas as pd

# Assuming df is your original DataFrame
df = pd.read_csv("Resources/State_funded_schools_inspections_and_outcomes_as_at_31_August_2023.csv", encoding='latin-1')

# Filter the DataFrame for 'Local authority' equals 'Birmingham'
West_Midlands_df = df[df['ofsted region'] == 'West Midlands']

# Display the first few rows of the filtered DataFrame
print(West_Midlands.head())

# %%
import pandas as pd
df = pd.read_csv("Resources/State_funded_schools_inspections_and_outcomes_as_at_31_August_2023.csv", encoding='ISO-8859-1')





# Define the region you want to filter on
target_region = 'West Midlands'

# Filter the DataFrame based on the 'Ofsted_region' column
west_midlands_df = df[df['Ofsted region'] == target_region]

# Display the first few rows of the filtered DataFrame
print(west_midlands_df.head())
# Out:
#                                                Web Link       URN    LAESTAB  \
# 1402  http://www.ofsted.gov.uk/inspection-reports/fi...  103120.0  3301001.0
# 1403  http://www.ofsted.gov.uk/inspection-reports/fi...  103121.0  3301002.0
# 1404  http://www.ofsted.gov.uk/inspection-reports/fi...  103122.0  3301006.0
# 1405  http://www.ofsted.gov.uk/inspection-reports/fi...  103123.0  3301008.0
# 1406  http://www.ofsted.gov.uk/inspection-reports/fi...  103124.0  3301009.0
#
#                               School name Ofsted phase  Type of education  \
# 1402  Bordesley Green East Nursery School      Nursery  LA Nursery School
# 1403              Brearley Nursery School      Nursery  LA Nursery School
# 1404        Garretts Green Nursery School      Nursery  LA Nursery School
# 1405         Perry Beeches Nursery School      Nursery  LA Nursery School
# 1406      St Thomas Centre Nursery School      Nursery  LA Nursery School
#
#      School open date Admissions policy      Sixth form  \
# 1402              NaN    Not applicable  Not applicable
# 1403              NaN    Not applicable  Not applicable
# 1404              NaN    Not applicable  Not applicable
# 1405              NaN    Not applicable  Not applicable
# 1406              NaN    Not applicable  Not applicable
#
#      Designated religious character  ...  \
# 1402                 Does not apply  ...
# 1403                 Does not apply  ...
# 1404                 Does not apply  ...
# 1405                 Does not apply  ...
# 1406                 Does not apply  ...
#
#      School type at time of previous graded inspection  \
# 1402                                 LA Nursery School
# 1403                                 LA Nursery School
# 1404                                 LA Nursery School
# 1405                                 LA Nursery School
# 1406                                 LA Nursery School
#
#      Previous graded inspection overall effectiveness  \
# 1402                                              2.0
# 1403                                              1.0
# 1404                                              2.0
# 1405                                              2.0
# 1406                                              1.0
#
#      Previous category of concern Previous quality of education  \
# 1402                          NaN                           9.0
# 1403                          NaN                           9.0
# 1404                          NaN                           9.0
# 1405                          NaN                           9.0
# 1406                          NaN                           9.0
#
#      Previous behaviour and attitudes Previous personal development  \
# 1402                              9.0                           9.0
# 1403                              9.0                           9.0
# 1404                              9.0                           9.0
# 1405                              9.0                           9.0
# 1406                              9.0                           9.0
#
#       Previous effectiveness of leadership and management  \
# 1402                                                2.0
# 1403                                                1.0
# 1404                                                2.0
# 1405                                                2.0
# 1406                                                1.0
#
#      Previous safeguarding is effective?  \
# 1402                                   9
# 1403                                   9
# 1404                                   9
# 1405                                   9
# 1406                                   9
#
#       Previous early years provision (where applicable)  \
# 1402                                                8.0
# 1403                                                1.0
# 1404                                                9.0
# 1405                                                2.0
# 1406                                                1.0
#
#      Previous sixth form provision (where applicable)
# 1402                                              9.0
# 1403                                              9.0
# 1404                                              9.0
# 1405                                              9.0
# 1406                                              9.0
#
# [5 rows x 78 columns]
# C:\Users\bella\AppData\Local\Temp\ipykernel_22972\176113275.py:2: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Resources/State_funded_schools_inspections_and_outcomes_as_at_31_August_2023.csv", encoding='ISO-8859-1')

# %%
west_midlands_df.to_csv("Resources/west_midlands_df.csv")

# %%
west_midlands_df.info
# Out:
# <bound method DataFrame.info of                                                 Web Link       URN    LAESTAB  \
# 1402   http://www.ofsted.gov.uk/inspection-reports/fi...  103120.0  3301001.0
# 1403   http://www.ofsted.gov.uk/inspection-reports/fi...  103121.0  3301002.0
# 1404   http://www.ofsted.gov.uk/inspection-reports/fi...  103122.0  3301006.0
# 1405   http://www.ofsted.gov.uk/inspection-reports/fi...  103123.0  3301008.0
# 1406   http://www.ofsted.gov.uk/inspection-reports/fi...  103124.0  3301009.0
# ...                                                  ...       ...        ...
# 21924  http://www.ofsted.gov.uk/inspection-reports/fi...  149639.0  8602240.0
# 21932  http://www.ofsted.gov.uk/inspection-reports/fi...  149649.0  8932117.0
# 21933  http://www.ofsted.gov.uk/inspection-reports/fi...  149651.0  8601105.0
# 21946  http://www.ofsted.gov.uk/inspection-reports/fi...  149678.0  3357008.0
# 21981  http://www.ofsted.gov.uk/inspection-reports/fi...  149872.0  3302018.0
#
#                                School name Ofsted phase  \
# 1402   Bordesley Green East Nursery School      Nursery
# 1403               Brearley Nursery School      Nursery
# 1404         Garretts Green Nursery School      Nursery
# 1405          Perry Beeches Nursery School      Nursery
# 1406       St Thomas Centre Nursery School      Nursery
# ...                                    ...          ...
# 21924               Green Lea First School      Primary
# 21932          Much Wenlock Primary School      Primary
# 21933                   The Bridge Academy          PRU
# 21946                  Mary Elliot Academy      Special
# 21981              The Oaks Primary School      Primary
#
#                              Type of education School open date  \
# 1402                         LA Nursery School              NaN
# 1403                         LA Nursery School              NaN
# 1404                         LA Nursery School              NaN
# 1405                         LA Nursery School              NaN
# 1406                         LA Nursery School              NaN
# ...                                        ...              ...
# 21924                        Academy Converter       01/04/2023
# 21932                        Academy Converter       01/04/2023
# 21933  Academy Alternative Provision Converter       01/08/2023
# 21946              Academy Special Sponsor Led       01/04/2023
# 21981                        Academy Converter       01/07/2023
#
#       Admissions policy                  Sixth form  \
# 1402     Not applicable              Not applicable
# 1403     Not applicable              Not applicable
# 1404     Not applicable              Not applicable
# 1405     Not applicable              Not applicable
# 1406     Not applicable              Not applicable
# ...                 ...                         ...
# 21924    Not applicable  Does not have a sixth form
# 21932    Not applicable  Does not have a sixth form
# 21933    Not applicable  Does not have a sixth form
# 21946    Not applicable            Has a sixth form
# 21981    Not applicable              Not applicable
#
#       Designated religious character  ...  \
# 1402                  Does not apply  ...
# 1403                  Does not apply  ...
# 1404                  Does not apply  ...
# 1405                  Does not apply  ...
# 1406                  Does not apply  ...
# ...                              ...  ...
# 21924                 Does not apply  ...
# 21932                 Does not apply  ...
# 21933                 Does not apply  ...
# 21946                 Does not apply  ...
# 21981                 Does not apply  ...
#
#       School type at time of previous graded inspection  \
# 1402                                  LA Nursery School
# 1403                                  LA Nursery School
# 1404                                  LA Nursery School
# 1405                                  LA Nursery School
# 1406                                  LA Nursery School
# ...                                                 ...
# 21924                                  Community School
# 21932                                  Community School
# 21933                               Pupil Referral Unit
# 21946                          Community Special School
# 21981                                  Community School
#
#       Previous graded inspection overall effectiveness  \
# 1402                                               2.0
# 1403                                               1.0
# 1404                                               2.0
# 1405                                               2.0
# 1406                                               1.0
# ...                                                ...
# 21924                                              2.0
# 21932                                              3.0
# 21933                                              2.0
# 21946                                              2.0
# 21981                                              3.0
#
#       Previous category of concern Previous quality of education  \
# 1402                           NaN                           9.0
# 1403                           NaN                           9.0
# 1404                           NaN                           9.0
# 1405                           NaN                           9.0
# 1406                           NaN                           9.0
# ...                            ...                           ...
# 21924                          NaN                           9.0
# 21932                          NaN                           9.0
# 21933                          NaN                           9.0
# 21946                          NaN                           9.0
# 21981                          NaN                           9.0
#
#       Previous behaviour and attitudes Previous personal development  \
# 1402                               9.0                           9.0
# 1403                               9.0                           9.0
# 1404                               9.0                           9.0
# 1405                               9.0                           9.0
# 1406                               9.0                           9.0
# ...                                ...                           ...
# 21924                              9.0                           9.0
# 21932                              9.0                           9.0
# 21933                              9.0                           9.0
# 21946                              9.0                           9.0
# 21981                              9.0                           9.0
#
#        Previous effectiveness of leadership and management  \
# 1402                                                 2.0
# 1403                                                 1.0
# 1404                                                 2.0
# 1405                                                 2.0
# 1406                                                 1.0
# ...                                                  ...
# 21924                                                2.0
# 21932                                                3.0
# 21933                                                2.0
# 21946                                                2.0
# 21981                                                3.0
#
#       Previous safeguarding is effective?  \
# 1402                                    9
# 1403                                    9
# 1404                                    9
# 1405                                    9
# 1406                                    9
# ...                                   ...
# 21924                                   9
# 21932                                   9
# 21933                                   9
# 21946                                   9
# 21981                                   9
#
#        Previous early years provision (where applicable)  \
# 1402                                                 8.0
# 1403                                                 1.0
# 1404                                                 9.0
# 1405                                                 2.0
# 1406                                                 1.0
# ...                                                  ...
# 21924                                                8.0
# 21932                                                2.0
# 21933                                                9.0
# 21946                                                9.0
# 21981                                                9.0
#
#       Previous sixth form provision (where applicable)
# 1402                                               9.0
# 1403                                               9.0
# 1404                                               9.0
# 1405                                               9.0
# 1406                                               9.0
# ...                                                ...
# 21924                                              9.0
# 21932                                              9.0
# 21933                                              9.0
# 21946                                              2.0
# 21981                                              9.0
#
# [2417 rows x 78 columns]>

# %%
import pandas as pd

# Assuming df is your DataFrame
df = pd.read_csv("your_file.csv", encoding='latin-1')

# Define the target region and local authority
target_region = 'West Midlands'
target_local_authority = 'Birmingham'

# Filter the DataFrame based on both conditions
filtered_df = df[(df['Ofsted_region'] == target_region) & (df['Local authority'] == target_local_authority)]

# Display the first few rows of the filtered DataFrame
print(filtered_df.head())
# Out:
# Index(['Web Link', 'URN', 'LAESTAB', 'School name', 'Ofsted phase',
#        'Type of education', 'School open date', 'Admissions policy',
#        'Sixth form', 'Designated religious character', 'Religious ethos',
#        'Faith grouping', 'Ofsted region', 'Region', 'Local authority',
#        'Parliamentary constituency', 'Multi-academy trust UID',
#        'Multi-academy trust name', 'Academy sponsor UID',
#        'Academy sponsor name', 'Postcode',
#        'Number of warning notices issued in 2022/23 academic year',
#        'The income deprivation affecting children index (IDACI) quintile',
#        'Total number of pupils', 'Statutory lowest age',
#        'Statutory highest age',
#        'Latest ungraded inspection number since last graded inspection',
#        'Does the ungraded inspection relate to the URN of the current school?',
#        'URN at time of the ungraded inspection',
#        'LAESTAB at time of the ungraded inspection',
#        'School name at time of the ungraded inspection',
#        'School type at time of the ungraded inspection',
#        'Number of ungraded inspections since the last graded inspection',
#        'Date of latest ungraded inspection',
#        'Ungraded inspection publication date',
#        'Did the latest ungraded inspection convert to a graded inspection?',
#        'Ungraded inspection overall outcome',
#        'Number of monitoring and urgent inspections since last graded inspection',
#        'Inspection number of latest graded inspection', 'Inspection type',
#        'Inspection type grouping', 'Event type grouping',
#        'Inspection start date', 'Inspection end date', 'Publication date',
#        'Does the latest graded inspection relate to the URN of the current school?',
#        'URN at time of latest graded inspection',
#        'LAESTAB at time of latest graded inspection',
#        'School name at time of latest graded inspection',
#        'School type at time of latest graded inspection',
#        'Current school type used for chart C6', 'Overall effectiveness',
#        'Category of concern', 'Quality of education',
#        'Behaviour and attitudes', 'Personal development',
#        'Effectiveness of leadership and management',
#        'Safeguarding is effective?',
#        'Early years provision (where applicable)',
#        'Sixth form provision (where applicable)', 'Previous inspection number',
#        'Previous inspection start date', 'Previous inspection end date',
#        'Previous publication date',
#        'Does the previous graded inspection relate to the URN of the current school?',
#        'URN at time of previous graded inspection',
#        'LAESTAB at time of previous graded inspection',
#        'School name at time of previous graded inspection',
#        'School type at time of previous graded inspection',
#        'Previous graded inspection overall effectiveness',
#        'Previous category of concern', 'Previous quality of education',
#        'Previous behaviour and attitudes', 'Previous personal development',
#        'Previous effectiveness of leadership and management',
#        'Previous safeguarding is effective?',
#        'Previous early years provision (where applicable)',
#        'Previous sixth form provision (where applicable)'],
#       dtype='object')

# %%
import pandas as pd
df = pd.read_csv("Resources/State_funded_schools_inspections_and_outcomes_as_at_31_August_2023.csv", encoding='ISO-8859-1')


# Define the target region and local authority
target_region = 'West Midlands'
target_local_authority = 'Birmingham'

# Filter the DataFrame based on both conditions
filtered_df = df[(df['Ofsted region'] == target_region) & (df['Local authority'] == target_local_authority)]

# Display the first few rows of the filtered DataFrame
print(filtered_df.head())
# Out:
#                                                Web Link       URN    LAESTAB  \
# 1402  http://www.ofsted.gov.uk/inspection-reports/fi...  103120.0  3301001.0
# 1403  http://www.ofsted.gov.uk/inspection-reports/fi...  103121.0  3301002.0
# 1404  http://www.ofsted.gov.uk/inspection-reports/fi...  103122.0  3301006.0
# 1405  http://www.ofsted.gov.uk/inspection-reports/fi...  103123.0  3301008.0
# 1406  http://www.ofsted.gov.uk/inspection-reports/fi...  103124.0  3301009.0
#
#                               School name Ofsted phase  Type of education  \
# 1402  Bordesley Green East Nursery School      Nursery  LA Nursery School
# 1403              Brearley Nursery School      Nursery  LA Nursery School
# 1404        Garretts Green Nursery School      Nursery  LA Nursery School
# 1405         Perry Beeches Nursery School      Nursery  LA Nursery School
# 1406      St Thomas Centre Nursery School      Nursery  LA Nursery School
#
#      School open date Admissions policy      Sixth form  \
# 1402              NaN    Not applicable  Not applicable
# 1403              NaN    Not applicable  Not applicable
# 1404              NaN    Not applicable  Not applicable
# 1405              NaN    Not applicable  Not applicable
# 1406              NaN    Not applicable  Not applicable
#
#      Designated religious character  ...  \
# 1402                 Does not apply  ...
# 1403                 Does not apply  ...
# 1404                 Does not apply  ...
# 1405                 Does not apply  ...
# 1406                 Does not apply  ...
#
#      School type at time of previous graded inspection  \
# 1402                                 LA Nursery School
# 1403                                 LA Nursery School
# 1404                                 LA Nursery School
# 1405                                 LA Nursery School
# 1406                                 LA Nursery School
#
#      Previous graded inspection overall effectiveness  \
# 1402                                              2.0
# 1403                                              1.0
# 1404                                              2.0
# 1405                                              2.0
# 1406                                              1.0
#
#      Previous category of concern Previous quality of education  \
# 1402                          NaN                           9.0
# 1403                          NaN                           9.0
# 1404                          NaN                           9.0
# 1405                          NaN                           9.0
# 1406                          NaN                           9.0
#
#      Previous behaviour and attitudes Previous personal development  \
# 1402                              9.0                           9.0
# 1403                              9.0                           9.0
# 1404                              9.0                           9.0
# 1405                              9.0                           9.0
# 1406                              9.0                           9.0
#
#       Previous effectiveness of leadership and management  \
# 1402                                                2.0
# 1403                                                1.0
# 1404                                                2.0
# 1405                                                2.0
# 1406                                                1.0
#
#      Previous safeguarding is effective?  \
# 1402                                   9
# 1403                                   9
# 1404                                   9
# 1405                                   9
# 1406                                   9
#
#       Previous early years provision (where applicable)  \
# 1402                                                8.0
# 1403                                                1.0
# 1404                                                9.0
# 1405                                                2.0
# 1406                                                1.0
#
#      Previous sixth form provision (where applicable)
# 1402                                              9.0
# 1403                                              9.0
# 1404                                              9.0
# 1405                                              9.0
# 1406                                              9.0
#
# [5 rows x 78 columns]
# C:\Users\bella\AppData\Local\Temp\ipykernel_22972\2578306121.py:2: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Resources/State_funded_schools_inspections_and_outcomes_as_at_31_August_2023.csv", encoding='ISO-8859-1')

# %%
filtered_df.info
# Out:
# <bound method DataFrame.info of                                                 Web Link       URN    LAESTAB  \
# 1402   http://www.ofsted.gov.uk/inspection-reports/fi...  103120.0  3301001.0
# 1403   http://www.ofsted.gov.uk/inspection-reports/fi...  103121.0  3301002.0
# 1404   http://www.ofsted.gov.uk/inspection-reports/fi...  103122.0  3301006.0
# 1405   http://www.ofsted.gov.uk/inspection-reports/fi...  103123.0  3301008.0
# 1406   http://www.ofsted.gov.uk/inspection-reports/fi...  103124.0  3301009.0
# ...                                                  ...       ...        ...
# 21642  http://www.ofsted.gov.uk/inspection-reports/fi...  149155.0  3304045.0
# 21728  http://www.ofsted.gov.uk/inspection-reports/fi...  149305.0  3302429.0
# 21766  http://www.ofsted.gov.uk/inspection-reports/fi...  149366.0  3302313.0
# 21831  http://www.ofsted.gov.uk/inspection-reports/fi...  149483.0  3302210.0
# 21981  http://www.ofsted.gov.uk/inspection-reports/fi...  149872.0  3302018.0
#
#                                       School name Ofsted phase  \
# 1402          Bordesley Green East Nursery School      Nursery
# 1403                      Brearley Nursery School      Nursery
# 1404                Garretts Green Nursery School      Nursery
# 1405                 Perry Beeches Nursery School      Nursery
# 1406              St Thomas Centre Nursery School      Nursery
# ...                                           ...          ...
# 21642  King Solomon International Business School    Secondary
# 21728     Holland House Infant School and Nursery      Primary
# 21766                  Heath Mount Primary School      Primary
# 21831             Highters Heath Community School      Primary
# 21981                     The Oaks Primary School      Primary
#
#          Type of education School open date Admissions policy  \
# 1402     LA Nursery School              NaN    Not applicable
# 1403     LA Nursery School              NaN    Not applicable
# 1404     LA Nursery School              NaN    Not applicable
# 1405     LA Nursery School              NaN    Not applicable
# 1406     LA Nursery School              NaN    Not applicable
# ...                    ...              ...               ...
# 21642          Free School       01/04/2022           Unknown
# 21728    Academy Converter       01/02/2023    Not applicable
# 21766    Academy Converter       01/10/2022    Not applicable
# 21831  Academy Sponsor Led       01/11/2022    Not applicable
# 21981    Academy Converter       01/07/2023    Not applicable
#
#                        Sixth form Designated religious character  ...  \
# 1402               Not applicable                 Does not apply  ...
# 1403               Not applicable                 Does not apply  ...
# 1404               Not applicable                 Does not apply  ...
# 1405               Not applicable                 Does not apply  ...
# 1406               Not applicable                 Does not apply  ...
# ...                           ...                            ...  ...
# 21642  Does not have a sixth form                        Unknown  ...
# 21728              Not applicable                 Does not apply  ...
# 21766              Not applicable                 Does not apply  ...
# 21831              Not applicable                 Does not apply  ...
# 21981              Not applicable                 Does not apply  ...
#
#       School type at time of previous graded inspection  \
# 1402                                  LA Nursery School
# 1403                                  LA Nursery School
# 1404                                  LA Nursery School
# 1405                                  LA Nursery School
# 1406                                  LA Nursery School
# ...                                                 ...
# 21642                                               NaN
# 21728                                  Community School
# 21766                                  Community School
# 21831                                  Community School
# 21981                                  Community School
#
#       Previous graded inspection overall effectiveness  \
# 1402                                               2.0
# 1403                                               1.0
# 1404                                               2.0
# 1405                                               2.0
# 1406                                               1.0
# ...                                                ...
# 21642                                              NaN
# 21728                                              2.0
# 21766                                              3.0
# 21831                                              3.0
# 21981                                              3.0
#
#       Previous category of concern Previous quality of education  \
# 1402                           NaN                           9.0
# 1403                           NaN                           9.0
# 1404                           NaN                           9.0
# 1405                           NaN                           9.0
# 1406                           NaN                           9.0
# ...                            ...                           ...
# 21642                          NaN                           NaN
# 21728                          NaN                           9.0
# 21766                          NaN                           9.0
# 21831                          NaN                           9.0
# 21981                          NaN                           9.0
#
#       Previous behaviour and attitudes Previous personal development  \
# 1402                               9.0                           9.0
# 1403                               9.0                           9.0
# 1404                               9.0                           9.0
# 1405                               9.0                           9.0
# 1406                               9.0                           9.0
# ...                                ...                           ...
# 21642                              NaN                           NaN
# 21728                              9.0                           9.0
# 21766                              9.0                           9.0
# 21831                              9.0                           9.0
# 21981                              9.0                           9.0
#
#        Previous effectiveness of leadership and management  \
# 1402                                                 2.0
# 1403                                                 1.0
# 1404                                                 2.0
# 1405                                                 2.0
# 1406                                                 1.0
# ...                                                  ...
# 21642                                                NaN
# 21728                                                2.0
# 21766                                                3.0
# 21831                                                3.0
# 21981                                                3.0
#
#       Previous safeguarding is effective?  \
# 1402                                    9
# 1403                                    9
# 1404                                    9
# 1405                                    9
# 1406                                    9
# ...                                   ...
# 21642                                 NaN
# 21728                                   9
# 21766                                 Yes
# 21831                                 Yes
# 21981                                   9
#
#        Previous early years provision (where applicable)  \
# 1402                                                 8.0
# 1403                                                 1.0
# 1404                                                 9.0
# 1405                                                 2.0
# 1406                                                 1.0
# ...                                                  ...
# 21642                                                NaN
# 21728                                                2.0
# 21766                                                3.0
# 21831                                                2.0
# 21981                                                9.0
#
#       Previous sixth form provision (where applicable)
# 1402                                               9.0
# 1403                                               9.0
# 1404                                               9.0
# 1405                                               9.0
# 1406                                               9.0
# ...                                                ...
# 21642                                              NaN
# 21728                                              9.0
# 21766                                              9.0
# 21831                                              9.0
# 21981                                              9.0
#
# [445 rows x 78 columns]>

# %%
filtered_df.to_csv("Resources/filtered_df.csv")

# %%
import pandas as pd
from geopy.geocoders import Nominatim

# Assuming df is your DataFrame
df = pd.read_csv("Resources/State_funded_schools_inspections_and_outcomes_as_at_31_August_2023.csv", encoding='ISO-8859-1')

# Define the target region and local authority
target_region = 'West Midlands'
target_local_authority = 'Birmingham'

# Filter the DataFrame based on both conditions
filtered1_df = df[(df['Ofsted region'] == target_region) & (df['Local authority'] == target_local_authority)]

# Create a geolocator using Nominatim
geolocator = Nominatim(user_agent="school_geocoder")

# Function to get latitude and longitude from address (Postcode)
def get_lat_lon(postcode):
    location = geolocator.geocode(postcode)
    return (location.latitude, location.longitude) if location else (None, None)

# Apply the function to the 'Postcode' column
filtered1_df['Latitude'], filtered1_df['Longitude'] = zip(*filtered1_df['Postcode'].apply(get_lat_lon))

# Display the first few rows of the updated DataFrame
print(filtered1_df.head())
# Out:
# C:\Users\bella\AppData\Local\Temp\ipykernel_22972\212678748.py:5: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Resources/State_funded_schools_inspections_and_outcomes_as_at_31_August_2023.csv", encoding='ISO-8859-1')
#                                                Web Link       URN    LAESTAB  \
# 1402  http://www.ofsted.gov.uk/inspection-reports/fi...  103120.0  3301001.0
# 1403  http://www.ofsted.gov.uk/inspection-reports/fi...  103121.0  3301002.0
# 1404  http://www.ofsted.gov.uk/inspection-reports/fi...  103122.0  3301006.0
# 1405  http://www.ofsted.gov.uk/inspection-reports/fi...  103123.0  3301008.0
# 1406  http://www.ofsted.gov.uk/inspection-reports/fi...  103124.0  3301009.0
#
#                               School name Ofsted phase  Type of education  \
# 1402  Bordesley Green East Nursery School      Nursery  LA Nursery School
# 1403              Brearley Nursery School      Nursery  LA Nursery School
# 1404        Garretts Green Nursery School      Nursery  LA Nursery School
# 1405         Perry Beeches Nursery School      Nursery  LA Nursery School
# 1406      St Thomas Centre Nursery School      Nursery  LA Nursery School
#
#      School open date Admissions policy      Sixth form  \
# 1402              NaN    Not applicable  Not applicable
# 1403              NaN    Not applicable  Not applicable
# 1404              NaN    Not applicable  Not applicable
# 1405              NaN    Not applicable  Not applicable
# 1406              NaN    Not applicable  Not applicable
#
#      Designated religious character  ... Previous category of concern  \
# 1402                 Does not apply  ...                          NaN
# 1403                 Does not apply  ...                          NaN
# 1404                 Does not apply  ...                          NaN
# 1405                 Does not apply  ...                          NaN
# 1406                 Does not apply  ...                          NaN
#
#      Previous quality of education Previous behaviour and attitudes  \
# 1402                           9.0                              9.0
# 1403                           9.0                              9.0
# 1404                           9.0                              9.0
# 1405                           9.0                              9.0
# 1406                           9.0                              9.0
#
#      Previous personal development  \
# 1402                           9.0
# 1403                           9.0
# 1404                           9.0
# 1405                           9.0
# 1406                           9.0
#
#      Previous effectiveness of leadership and management  \
# 1402                                                2.0
# 1403                                                1.0
# 1404                                                2.0
# 1405                                                2.0
# 1406                                                1.0
#
#      Previous safeguarding is effective?  \
# 1402                                   9
# 1403                                   9
# 1404                                   9
# 1405                                   9
# 1406                                   9
#
#       Previous early years provision (where applicable)  \
# 1402                                                8.0
# 1403                                                1.0
# 1404                                                9.0
# 1405                                                2.0
# 1406                                                1.0
#
#      Previous sixth form provision (where applicable)   Latitude Longitude
# 1402                                              9.0  52.477893 -1.813013
# 1403                                              9.0  52.491611 -1.900372
# 1404                                              9.0  52.466995 -1.791982
# 1405                                              9.0  52.539473 -1.908793
# 1406                                              9.0  52.454691 -1.901244
#
# [5 rows x 80 columns]
# C:\Users\bella\AppData\Local\Temp\ipykernel_22972\212678748.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered1_df['Latitude'], filtered1_df['Longitude'] = zip(*filtered1_df['Postcode'].apply(get_lat_lon))
# C:\Users\bella\AppData\Local\Temp\ipykernel_22972\212678748.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered1_df['Latitude'], filtered1_df['Longitude'] = zip(*filtered1_df['Postcode'].apply(get_lat_lon))

# %%
filtered1_df.to_csv("Resources/filtered1_df.csv")

# %%
import sqlite3
import pandas as pd
# Import dependencies.
import matplotlib
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt
import pandas as pd

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, text, inspect, func

# %%
df2 = pd.read_csv("Resources/filtered1_df.csv", encoding='latin-1')
